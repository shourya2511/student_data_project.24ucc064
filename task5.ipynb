# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('final.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 school  age address famsize Pstatus     Mjob      Fjob  reason  \
# 0           0     GP   18       U     GT3       A  at_home   teacher  course
# 1           1     GP   17       U     GT3       T  at_home     other  course
# 2           2     GP   15       U     LE3       T  at_home     other   other
# 3           3     GP   15       U     GT3       T   health  services    home
# 4           4     GP   16       U     GT3       T    other     other    home
#
#   guardian  ...  non_study_time  grade  GPA  Alcohol_Consumption  \
# 0   mother  ...               4      E    4                    1
# 1   father  ...               3      E    4                    1
# 2   mother  ...               2      D    5                    2
# 3   mother  ...               2      B    7                    1
# 4   father  ...               2      D    5                    2
#
#    Parental_Education  age_standardized  studytime_standardized  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              395 non-null    int64
#  1   school                  395 non-null    object
#  2   age                     395 non-null    int64
#  3   address                 395 non-null    object
#  4   famsize                 395 non-null    object
#  5   Pstatus                 395 non-null    object
#  6   Mjob                    395 non-null    object
#  7   Fjob                    395 non-null    object
#  8   reason                  395 non-null    object
#  9   guardian                395 non-null    object
#  10  traveltime              395 non-null    int64
#  11  studytime               395 non-null    int64
#  12  failures                395 non-null    int64
#  13  schoolsup               395 non-null    int64
# ...

# %% [markdown]
# This Dataset is mostly uniform. key insight is that the student who generally performs well in G1 also performs well in upcoming terms
#
# some interesting insights
#
# relationships,famsize,parental education does not greatly affect the GPA of a student.
