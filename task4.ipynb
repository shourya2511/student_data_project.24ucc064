# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('modified2_table.csv')

# %%
df
# Out:
#     school sex  age address famsize Pstatus      Mjob      Fjob  reason  \
# 0       GP   F   18       U     GT3       A   at_home   teacher  course
# 1       GP   F   17       U     GT3       T   at_home     other  course
# 2       GP   F   15       U     LE3       T   at_home     other   other
# 3       GP   F   15       U     GT3       T    health  services    home
# 4       GP   F   16       U     GT3       T     other     other    home
# ..     ...  ..  ...     ...     ...     ...       ...       ...     ...
# 390     MS   M   20       U     LE3       A  services  services  course
# 391     MS   M   17       U     LE3       T  services  services  course
# 392     MS   M   21       R     GT3       T     other     other  course
# 393     MS   M   18       R     LE3       T  services     other  course
# 394     MS   M   19       U     LE3       T     other   at_home  course
#
#     guardian  ...  health  absences  G1  G2  G3 non_study_time grade GPA  \
# ...

# %%
df['age_standardized'] = (df['age'] - df['age'].mean()) / df['age'].std()

# %%
df['studytime_standardized'] = (df['studytime'] - df['studytime'].mean()) / df['studytime'].std()

# %%
np.std(df['studytime_standardized'])
# Out:
# np.float64(0.9987333750458026)

# %%
 df['GPA_standardized'] = (df['GPA'] - df['GPA'].mean()) / df['GPA'].std()

# %%
df['absences_standardized'] = (df['absences'] - df['absences'].mean()) / df['absences'].std()

# %%
 df['GPA_standardized'].describe()
# Out:
# count    3.950000e+02
# mean    -4.047395e-17
# std      1.000000e+00
# min     -2.849533e+00
# 25%     -6.265596e-01
# 50%      1.144315e-01
# 75%      8.554227e-01
# max      3.078396e+00
# Name: GPA_standardized, dtype: float64

# %%
df['absences_standardized'].describe()
# Out:
# count    3.950000e+02
# mean    -4.497106e-17
# std      1.000000e+00
# min     -7.133316e-01
# 25%     -7.133316e-01
# 50%     -2.135250e-01
# 75%      2.862816e-01
# max      8.658042e+00
# Name: absences_standardized, dtype: float64

# %%
df = pd.get_dummies(df, columns=['sex'], drop_first=True)

# %%
df
# Out:
#     school  age address famsize Pstatus      Mjob      Fjob  reason guardian  \
# 0       GP   18       U     GT3       A   at_home   teacher  course   mother
# 1       GP   17       U     GT3       T   at_home     other  course   father
# 2       GP   15       U     LE3       T   at_home     other   other   mother
# 3       GP   15       U     GT3       T    health  services    home   mother
# 4       GP   16       U     GT3       T     other     other    home   father
# ..     ...  ...     ...     ...     ...       ...       ...     ...      ...
# 390     MS   20       U     LE3       A  services  services  course    other
# 391     MS   17       U     LE3       T  services  services  course   mother
# 392     MS   21       R     GT3       T     other     other  course    other
# 393     MS   18       R     LE3       T  services     other  course   mother
# 394     MS   19       U     LE3       T     other   at_home  course   father
#
# ...

# %%
df['sex_M'] = df['sex_M'].replace({True: 1, False: 0})
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_31172\415894869.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['sex_M'] = df['sex_M'].replace({True: 1, False: 0})

# %%
df
# Out:
#     school  age address famsize Pstatus      Mjob      Fjob  reason guardian  \
# 0       GP   18       U     GT3       A   at_home   teacher  course   mother
# 1       GP   17       U     GT3       T   at_home     other  course   father
# 2       GP   15       U     LE3       T   at_home     other   other   mother
# 3       GP   15       U     GT3       T    health  services    home   mother
# 4       GP   16       U     GT3       T     other     other    home   father
# ..     ...  ...     ...     ...     ...       ...       ...     ...      ...
# 390     MS   20       U     LE3       A  services  services  course    other
# 391     MS   17       U     LE3       T  services  services  course   mother
# 392     MS   21       R     GT3       T     other     other  course    other
# 393     MS   18       R     LE3       T  services     other  course   mother
# 394     MS   19       U     LE3       T     other   at_home  course   father
#
# ...

# %%
df['Parental_Education'].value_counts() # already encoded
# Out:
# Parental_Education
# 2    162
# 4    128
# 3     64
# 1     39
# 0      2
# Name: count, dtype: int64

# %%
# List of columns to convert
yes_no_cols = ['schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']

# Map 'yes' → 1, 'no' → 0
df[yes_no_cols] = df[yes_no_cols].replace({'yes': 1, 'no': 0})

# Verify
print(df.head())
# Out:
#   school  age address famsize Pstatus     Mjob      Fjob  reason guardian  \
# 0     GP   18       U     GT3       A  at_home   teacher  course   mother
# 1     GP   17       U     GT3       T  at_home     other  course   father
# 2     GP   15       U     LE3       T  at_home     other   other   mother
# 3     GP   15       U     GT3       T   health  services    home   mother
# 4     GP   16       U     GT3       T    other     other    home   father
#
#    traveltime  ...  non_study_time  grade  GPA  Alcohol_Consumption  \
# 0           2  ...               4      E    4                    1
# 1           1  ...               3      E    4                    1
# 2           1  ...               2      D    5                    2
# 3           1  ...               2      B    7                    1
# 4           1  ...               2      D    5                    2
#
#    Parental_Education  age_standardized  studytime_standardized  \
# ...

# %%
df
# Out:
#     school  age address famsize Pstatus      Mjob      Fjob  reason guardian  \
# 0       GP   18       U     GT3       A   at_home   teacher  course   mother
# 1       GP   17       U     GT3       T   at_home     other  course   father
# 2       GP   15       U     LE3       T   at_home     other   other   mother
# 3       GP   15       U     GT3       T    health  services    home   mother
# 4       GP   16       U     GT3       T     other     other    home   father
# ..     ...  ...     ...     ...     ...       ...       ...     ...      ...
# 390     MS   20       U     LE3       A  services  services  course    other
# 391     MS   17       U     LE3       T  services  services  course   mother
# 392     MS   21       R     GT3       T     other     other  course    other
# 393     MS   18       R     LE3       T  services     other  course   mother
# 394     MS   19       U     LE3       T     other   at_home  course   father
#
# ...

# %%
df
# Out:
#     school  age address famsize Pstatus      Mjob      Fjob  reason guardian  \
# 0       GP   18       U     GT3       A   at_home   teacher  course   mother
# 1       GP   17       U     GT3       T   at_home     other  course   father
# 2       GP   15       U     LE3       T   at_home     other   other   mother
# 3       GP   15       U     GT3       T    health  services    home   mother
# 4       GP   16       U     GT3       T     other     other    home   father
# ..     ...  ...     ...     ...     ...       ...       ...     ...      ...
# 390     MS   20       U     LE3       A  services  services  course    other
# 391     MS   17       U     LE3       T  services  services  course   mother
# 392     MS   21       R     GT3       T     other     other  course    other
# 393     MS   18       R     LE3       T  services     other  course   mother
# 394     MS   19       U     LE3       T     other   at_home  course   father
#
# ...

# %%
df.to_csv('final.csv')
